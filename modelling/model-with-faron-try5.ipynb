# %%
import pandas as pd
import numpy as np
import xgboost as xgb

# %matplotlib inline

from sklearn.metrics import matthews_corrcoef
import matplotlib.pyplot as plt
from numba import jit

@jit
def mcc(tp, tn, fp, fn):
    sup = tp * tn - fp * fn
    inf = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    if inf==0:
        return 0
    else:
        return sup / np.sqrt(inf)

@jit
def eval_mcc(y_true, y_prob, show=False):
    idx = np.argsort(y_prob)
    y_true_sort = y_true[idx]
    n = y_true.shape[0]
    nump = 1.0 * np.sum(y_true) # number of positive
    numn = n - nump # number of negative
    tp = nump
    tn = 0.0
    fp = numn
    fn = 0.0
    best_mcc = 0.0
    best_id = -1
    prev_proba = -1
    best_proba = -1
    mccs = np.zeros(n)
    for i in range(n):
        # all items with idx < i are predicted negative while others are predicted positive
        # only evaluate mcc when probability changes
        proba = y_prob[idx[i]]
        if proba != prev_proba:
            prev_proba = proba
            new_mcc = mcc(tp, tn, fp, fn)
            if new_mcc >= best_mcc:
                best_mcc = new_mcc
                best_id = i
                best_proba = proba
        mccs[i] = new_mcc
        if y_true_sort[i] == 1:
            tp -= 1.0
            fn += 1.0
        else:
            fp -= 1.0
            tn += 1.0
    if show:
        y_pred = (y_prob >= best_proba).astype(int)
        score = matthews_corrcoef(y_true, y_pred)
        print(score, best_mcc)
        plt.plot(mccs)
        return best_proba, best_mcc, y_pred
    else:
        return best_mcc

def mcc_eval(y_prob, dtrain):
    y_true = dtrain.get_label()
    best_mcc = eval_mcc(y_true, y_prob)
    return 'MCC', best_mcc

# %%
dtrain = xgb.DMatrix('dtrain.buffer')
dvalid = xgb.DMatrix('dvalid.buffer')

# %%
dtrain.get_label().sum()+dvalid.get_label().sum()
# Out:
# 6879.0

# %%
dtrain.num_row()+dvalid.num_row()
# Out:
# 1183747

# %%
'''
df1 = pd.read_csv('../input_orig/train_numeric.csv', usecols=['Id','Response'])

from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1, df1.Response.values, test_size=0.1, random_state=42, stratify=df1.Response.values)

dvalid = dtrain.slice(X_test.index)
dvalid.num_row(), X_test.shape
dtrain = dtrain.slice(X_train.index)
dtrain.num_row(), X_train.shape

#dtrain.save_binary('dtrain.buffer')
#dvalid.save_binary('dvalid.buffer')

# %%
y = dtrain.get_label()
prior = np.sum(y) / (1.*len(y))

# %%
spw = 1176868/6879.0

# %%
prior1 = 6879.0/1183747

# %%
xgb_params1 = {
    'colsample_bytree': 1,
    'colsample_bylevel': 1,
    'subsample': 1,
    'learning_rate': 0.01,
    'max_depth': 48,
    'min_child_weight': 1,
    'gamma': 0.1,
    'base_score': prior1,
    'tree_method': 'exact',
    'objective': 'binary:logistic',
    'silent': 0,
    'seed': 12,
    'nthread': 22
}
evals  = [(dtrain,'train'), (dvalid,'eval')]
bst1 = xgb.train(xgb_params1, dtrain, num_boost_round=50000, early_stopping_rounds=100, 
                 evals=evals, verbose_eval=1, feval=mcc_eval, maximize=True)
# Out:
# [0]	train-MCC:0.355146	eval-MCC:0.348413
# Multiple eval metrics have been passed: 'eval-MCC' will be used for early stopping.
#
# Will train until eval-MCC hasn't improved in 100 rounds.
# [1]	train-MCC:0.378132	eval-MCC:0.371776
# [2]	train-MCC:0.382295	eval-MCC:0.380588
# [3]	train-MCC:0.387847	eval-MCC:0.381795
# [4]	train-MCC:0.402856	eval-MCC:0.384382
# [5]	train-MCC:0.416661	eval-MCC:0.389715
# [6]	train-MCC:0.42947	eval-MCC:0.389715
# [7]	train-MCC:0.444499	eval-MCC:0.390397
# [8]	train-MCC:0.452188	eval-MCC:0.39205
# [9]	train-MCC:0.461239	eval-MCC:0.392256
# [10]	train-MCC:0.475856	eval-MCC:0.392465
# [11]	train-MCC:0.479727	eval-MCC:0.392756
# [12]	train-MCC:0.491181	eval-MCC:0.392256
# [13]	train-MCC:0.499299	eval-MCC:0.394566
# [14]	train-MCC:0.512438	eval-MCC:0.396966
# [15]	train-MCC:0.525072	eval-MCC:0.396702
# [16]	train-MCC:0.537496	eval-MCC:0.397589
# [17]	train-MCC:0.550044	eval-MCC:0.396471
# [18]	train-MCC:0.5613	eval-MCC:0.395352
# [19]	train-MCC:0.572599	eval-MCC:0.394682
# [20]	train-MCC:0.580398	eval-MCC:0.39538
# [21]	train-MCC:0.588438	eval-MCC:0.395139
# [22]	train-MCC:0.597254	eval-MCC:0.394456
# [23]	train-MCC:0.608025	eval-MCC:0.395857
# [24]	train-MCC:0.618068	eval-MCC:0.39714
# [25]	train-MCC:0.625063	eval-MCC:0.397382
# [26]	train-MCC:0.633872	eval-MCC:0.398066
# [27]	train-MCC:0.639728	eval-MCC:0.397382
# [28]	train-MCC:0.647958	eval-MCC:0.399376
# [29]	train-MCC:0.656156	eval-MCC:0.400026
# [30]	train-MCC:0.663286	eval-MCC:0.39982
# [31]	train-MCC:0.668376	eval-MCC:0.399807
# [32]	train-MCC:0.675041	eval-MCC:0.399571
# [33]	train-MCC:0.681753	eval-MCC:0.400476
# [34]	train-MCC:0.68649	eval-MCC:0.400287
# [35]	train-MCC:0.692922	eval-MCC:0.402244
# [36]	train-MCC:0.697845	eval-MCC:0.402033
# [37]	train-MCC:0.703896	eval-MCC:0.402244
# [38]	train-MCC:0.711271	eval-MCC:0.402709
# [39]	train-MCC:0.71486	eval-MCC:0.402505
# [40]	train-MCC:0.722207	eval-MCC:0.403387
# [41]	train-MCC:0.727723	eval-MCC:0.404949
# [42]	train-MCC:0.733616	eval-MCC:0.404949
# [43]	train-MCC:0.739495	eval-MCC:0.405634
# [44]	train-MCC:0.744096	eval-MCC:0.405634
# [45]	train-MCC:0.749466	eval-MCC:0.405634
# [46]	train-MCC:0.754097	eval-MCC:0.406511
# [47]	train-MCC:0.756289	eval-MCC:0.407387
# [48]	train-MCC:0.760084	eval-MCC:0.406703
# [49]	train-MCC:0.762749	eval-MCC:0.406024
# [50]	train-MCC:0.766906	eval-MCC:0.406839
# [51]	train-MCC:0.771384	eval-MCC:0.406631
# [52]	train-MCC:0.773384	eval-MCC:0.407265
# [53]	train-MCC:0.776474	eval-MCC:0.406631
# [54]	train-MCC:0.779812	eval-MCC:0.406839
# [55]	train-MCC:0.782106	eval-MCC:0.406899
# [56]	train-MCC:0.785116	eval-MCC:0.407772
# [57]	train-MCC:0.787904	eval-MCC:0.407097
# [58]	train-MCC:0.790673	eval-MCC:0.407097
# [59]	train-MCC:0.791673	eval-MCC:0.407097
# [60]	train-MCC:0.795315	eval-MCC:0.406862
# [61]	train-MCC:0.798205	eval-MCC:0.40789
# [62]	train-MCC:0.800589	eval-MCC:0.40816
# [63]	train-MCC:0.802443	eval-MCC:0.409038
# [64]	train-MCC:0.803713	eval-MCC:0.409038
# [65]	train-MCC:0.804909	eval-MCC:0.409038
# [66]	train-MCC:0.807149	eval-MCC:0.409653
# [67]	train-MCC:0.808133	eval-MCC:0.410367
# [68]	train-MCC:0.80907	eval-MCC:0.411085
# [69]	train-MCC:0.810398	eval-MCC:0.411806
# [70]	train-MCC:0.812445	eval-MCC:0.411806
# [71]	train-MCC:0.814216	eval-MCC:0.411806
# [72]	train-MCC:0.815798	eval-MCC:0.411806
# [73]	train-MCC:0.816528	eval-MCC:0.411806
# [74]	train-MCC:0.817648	eval-MCC:0.411806
# [75]	train-MCC:0.818986	eval-MCC:0.411806
# [76]	train-MCC:0.820527	eval-MCC:0.411806
# [77]	train-MCC:0.821433	eval-MCC:0.411806
# [78]	train-MCC:0.82274	eval-MCC:0.412759
# [79]	train-MCC:0.823839	eval-MCC:0.412931
# [80]	train-MCC:0.825498	eval-MCC:0.412931
# [81]	train-MCC:0.82663	eval-MCC:0.412931
# [82]	train-MCC:0.828215	eval-MCC:0.413105
# [83]	train-MCC:0.828857	eval-MCC:0.413105
# [84]	train-MCC:0.829096	eval-MCC:0.413293
# [85]	train-MCC:0.830073	eval-MCC:0.413649
# [86]	train-MCC:0.831231	eval-MCC:0.414326
# [87]	train-MCC:0.832291	eval-MCC:0.415006
# [88]	train-MCC:0.832525	eval-MCC:0.414158
# [89]	train-MCC:0.833652	eval-MCC:0.414158
# [90]	train-MCC:0.834345	eval-MCC:0.414158
# [91]	train-MCC:0.835534	eval-MCC:0.414326
# [92]	train-MCC:0.836264	eval-MCC:0.415006
# [93]	train-MCC:0.836663	eval-MCC:0.415006
# [94]	train-MCC:0.837398	eval-MCC:0.415184
# [95]	train-MCC:0.838899	eval-MCC:0.415518
# [96]	train-MCC:0.840195	eval-MCC:0.415518
# [97]	train-MCC:0.840586	eval-MCC:0.416044
# [98]	train-MCC:0.841355	eval-MCC:0.416903
# [99]	train-MCC:0.841759	eval-MCC:0.416209
# [100]	train-MCC:0.842082	eval-MCC:0.416209
# [101]	train-MCC:0.842486	eval-MCC:0.416209
# [102]	train-MCC:0.84326	eval-MCC:0.416209
# [103]	train-MCC:0.844306	eval-MCC:0.416209
# [104]	train-MCC:0.844973	eval-MCC:0.416209
# [105]	train-MCC:0.845582	eval-MCC:0.416209
# [106]	train-MCC:0.845988	eval-MCC:0.415518
# [107]	train-MCC:0.846596	eval-MCC:0.415518
# [108]	train-MCC:0.846906	eval-MCC:0.415518
# [109]	train-MCC:0.847542	eval-MCC:0.415006
# [110]	train-MCC:0.848346	eval-MCC:0.41569
# [111]	train-MCC:0.848632	eval-MCC:0.41569
# [112]	train-MCC:0.848927	eval-MCC:0.415349
# [113]	train-MCC:0.849465	eval-MCC:0.415349
# [114]	train-MCC:0.850009	eval-MCC:0.41569
# [115]	train-MCC:0.850579	eval-MCC:0.416377
# [116]	train-MCC:0.851137	eval-MCC:0.416377
# [117]	train-MCC:0.85185	eval-MCC:0.415518
# [118]	train-MCC:0.852526	eval-MCC:0.416377
# [119]	train-MCC:0.853149	eval-MCC:0.416377
# [120]	train-MCC:0.854091	eval-MCC:0.415518
# [121]	train-MCC:0.854666	eval-MCC:0.415518
# [122]	train-MCC:0.855207	eval-MCC:0.415518
# [123]	train-MCC:0.855679	eval-MCC:0.415518
# [124]	train-MCC:0.856202	eval-MCC:0.415006
# [125]	train-MCC:0.856397	eval-MCC:0.41483
# [126]	train-MCC:0.856695	eval-MCC:0.415186
# [127]	train-MCC:0.857297	eval-MCC:0.415186
# [128]	train-MCC:0.857951	eval-MCC:0.415186
# [129]	train-MCC:0.858269	eval-MCC:0.415186
# [130]	train-MCC:0.85879	eval-MCC:0.415186
# [131]	train-MCC:0.859434	eval-MCC:0.415186
# [132]	train-MCC:0.859832	eval-MCC:0.41483
# [133]	train-MCC:0.859946	eval-MCC:0.415006
# [134]	train-MCC:0.86029	eval-MCC:0.415518
# [135]	train-MCC:0.860715	eval-MCC:0.415518
# [136]	train-MCC:0.861276	eval-MCC:0.414887
# [137]	train-MCC:0.861729	eval-MCC:0.415555
# [138]	train-MCC:0.862785	eval-MCC:0.415555
# [139]	train-MCC:0.863319	eval-MCC:0.41569
# [140]	train-MCC:0.863623	eval-MCC:0.416226
# [141]	train-MCC:0.863957	eval-MCC:0.41569
# [142]	train-MCC:0.86431	eval-MCC:0.416377
# [143]	train-MCC:0.864849	eval-MCC:0.415865
# [144]	train-MCC:0.865344	eval-MCC:0.41569
# [145]	train-MCC:0.86587	eval-MCC:0.41569
# [146]	train-MCC:0.866075	eval-MCC:0.416044
# [147]	train-MCC:0.866285	eval-MCC:0.416548
# [148]	train-MCC:0.866521	eval-MCC:0.416723
# [149]	train-MCC:0.86681	eval-MCC:0.416723
# [150]	train-MCC:0.867108	eval-MCC:0.416723
# [151]	train-MCC:0.867372	eval-MCC:0.416723
# [152]	train-MCC:0.86793	eval-MCC:0.416723
# [153]	train-MCC:0.86844	eval-MCC:0.4169
# [154]	train-MCC:0.868945	eval-MCC:0.417158
# [155]	train-MCC:0.869352	eval-MCC:0.416507
# [156]	train-MCC:0.869824	eval-MCC:0.416939
# [157]	train-MCC:0.870452	eval-MCC:0.416939
# [158]	train-MCC:0.870981	eval-MCC:0.416723
# [159]	train-MCC:0.871533	eval-MCC:0.417357
# [160]	train-MCC:0.872042	eval-MCC:0.416939
# [161]	train-MCC:0.872507	eval-MCC:0.417357
# [162]	train-MCC:0.872962	eval-MCC:0.417357
# [163]	train-MCC:0.873601	eval-MCC:0.416937
# [164]	train-MCC:0.873974	eval-MCC:0.416937
# [165]	train-MCC:0.874391	eval-MCC:0.416937
# [166]	train-MCC:0.874655	eval-MCC:0.417582
# [167]	train-MCC:0.875083	eval-MCC:0.417146
# [168]	train-MCC:0.875542	eval-MCC:0.417643
# [169]	train-MCC:0.875927	eval-MCC:0.417643
# [170]	train-MCC:0.876435	eval-MCC:0.417643
# [171]	train-MCC:0.876943	eval-MCC:0.417935
# [172]	train-MCC:0.877157	eval-MCC:0.418305
# [173]	train-MCC:0.877429	eval-MCC:0.417935
# [174]	train-MCC:0.878024	eval-MCC:0.41897
# [175]	train-MCC:0.878547	eval-MCC:0.41897
# [176]	train-MCC:0.878852	eval-MCC:0.41897
# [177]	train-MCC:0.879214	eval-MCC:0.41897
# [178]	train-MCC:0.879589	eval-MCC:0.419638
# [179]	train-MCC:0.88032	eval-MCC:0.418787
# [180]	train-MCC:0.880997	eval-MCC:0.418787
# [181]	train-MCC:0.881604	eval-MCC:0.419051
# [182]	train-MCC:0.882236	eval-MCC:0.418842
# [183]	train-MCC:0.882658	eval-MCC:0.418881
# [184]	train-MCC:0.883369	eval-MCC:0.419343
# [185]	train-MCC:0.884113	eval-MCC:0.419343
# [186]	train-MCC:0.885029	eval-MCC:0.41897
# [187]	train-MCC:0.886038	eval-MCC:0.41946
# [188]	train-MCC:0.886834	eval-MCC:0.419481
# [189]	train-MCC:0.887442	eval-MCC:0.419481
# [190]	train-MCC:0.887995	eval-MCC:0.419638
# [191]	train-MCC:0.888808	eval-MCC:0.419481
# [192]	train-MCC:0.889378	eval-MCC:0.419481
# [193]	train-MCC:0.890036	eval-MCC:0.419481
# [194]	train-MCC:0.890691	eval-MCC:0.420326
# [195]	train-MCC:0.89156	eval-MCC:0.420319
# [196]	train-MCC:0.892283	eval-MCC:0.419693
# [197]	train-MCC:0.892964	eval-MCC:0.419476
# [198]	train-MCC:0.893872	eval-MCC:0.419476
# [199]	train-MCC:0.894251	eval-MCC:0.419476
# [200]	train-MCC:0.894968	eval-MCC:0.419481
# [201]	train-MCC:0.89581	eval-MCC:0.419481
# [202]	train-MCC:0.896757	eval-MCC:0.419687
# [203]	train-MCC:0.897647	eval-MCC:0.420191
# [204]	train-MCC:0.898132	eval-MCC:0.420381
# [205]	train-MCC:0.898435	eval-MCC:0.420191
# [206]	train-MCC:0.899144	eval-MCC:0.420326
# [207]	train-MCC:0.900616	eval-MCC:0.42077
# [208]	train-MCC:0.901109	eval-MCC:0.421882
# [209]	train-MCC:0.901862	eval-MCC:0.422071
# [210]	train-MCC:0.902853	eval-MCC:0.421419
# [211]	train-MCC:0.903558	eval-MCC:0.421419
# [212]	train-MCC:0.904409	eval-MCC:0.421419
# [213]	train-MCC:0.905356	eval-MCC:0.421419
# [214]	train-MCC:0.906002	eval-MCC:0.420969
# [215]	train-MCC:0.906754	eval-MCC:0.421614
# [216]	train-MCC:0.907998	eval-MCC:0.421614
# [217]	train-MCC:0.909012	eval-MCC:0.421811
# [218]	train-MCC:0.909701	eval-MCC:0.421811
# [219]	train-MCC:0.910401	eval-MCC:0.421614
# [220]	train-MCC:0.911201	eval-MCC:0.420969
# [221]	train-MCC:0.911974	eval-MCC:0.421614
# [222]	train-MCC:0.912747	eval-MCC:0.421614
# [223]	train-MCC:0.913229	eval-MCC:0.421614
# [224]	train-MCC:0.914086	eval-MCC:0.421614
# [225]	train-MCC:0.914882	eval-MCC:0.421614
# [226]	train-MCC:0.915992	eval-MCC:0.421614
# [227]	train-MCC:0.916697	eval-MCC:0.421614
# [228]	train-MCC:0.917609	eval-MCC:0.421614
# [229]	train-MCC:0.918359	eval-MCC:0.421614
# [230]	train-MCC:0.918913	eval-MCC:0.421614
# [231]	train-MCC:0.919712	eval-MCC:0.421811
# [232]	train-MCC:0.920347	eval-MCC:0.421811
# [233]	train-MCC:0.921124	eval-MCC:0.421811
# [234]	train-MCC:0.921607	eval-MCC:0.421614
# [235]	train-MCC:0.922225	eval-MCC:0.422262
# [236]	train-MCC:0.92293	eval-MCC:0.422262
# [237]	train-MCC:0.923402	eval-MCC:0.422262
# [238]	train-MCC:0.92417	eval-MCC:0.422262
# [239]	train-MCC:0.92485	eval-MCC:0.421614
# [240]	train-MCC:0.925435	eval-MCC:0.422262
# [241]	train-MCC:0.926096	eval-MCC:0.422456
# [242]	train-MCC:0.926511	eval-MCC:0.422456
# [243]	train-MCC:0.927374	eval-MCC:0.421419
# [244]	train-MCC:0.927817	eval-MCC:0.421419
# [245]	train-MCC:0.928375	eval-MCC:0.421227
# [246]	train-MCC:0.929055	eval-MCC:0.421227
# [247]	train-MCC:0.929531	eval-MCC:0.421882
# [248]	train-MCC:0.930286	eval-MCC:0.421697
# [249]	train-MCC:0.93079	eval-MCC:0.421697
# [250]	train-MCC:0.931552	eval-MCC:0.421697
# [251]	train-MCC:0.932201	eval-MCC:0.421697
# [252]	train-MCC:0.933179	eval-MCC:0.421697
# [253]	train-MCC:0.93355	eval-MCC:0.422359
# [254]	train-MCC:0.934307	eval-MCC:0.422359
# [255]	train-MCC:0.934923	eval-MCC:0.422359
# [256]	train-MCC:0.93549	eval-MCC:0.421697
# [257]	train-MCC:0.93644	eval-MCC:0.421697
# [258]	train-MCC:0.937041	eval-MCC:0.421514
# [259]	train-MCC:0.937782	eval-MCC:0.421697
# [260]	train-MCC:0.93846	eval-MCC:0.421697
# [261]	train-MCC:0.939261	eval-MCC:0.421697
# [262]	train-MCC:0.939904	eval-MCC:0.421514
# [263]	train-MCC:0.940723	eval-MCC:0.421697
# [264]	train-MCC:0.941362	eval-MCC:0.422359
# [265]	train-MCC:0.942079	eval-MCC:0.422359
# [266]	train-MCC:0.942932	eval-MCC:0.422359
# [267]	train-MCC:0.943557	eval-MCC:0.421697
# [268]	train-MCC:0.944033	eval-MCC:0.421697
# [269]	train-MCC:0.944709	eval-MCC:0.420851
# [270]	train-MCC:0.945291	eval-MCC:0.421697
# [271]	train-MCC:0.945966	eval-MCC:0.421514
# [272]	train-MCC:0.946521	eval-MCC:0.421514
# [273]	train-MCC:0.947286	eval-MCC:0.421514
# [274]	train-MCC:0.947563	eval-MCC:0.420851
# [275]	train-MCC:0.948392	eval-MCC:0.421514
# [276]	train-MCC:0.948686	eval-MCC:0.420851
# [277]	train-MCC:0.9493	eval-MCC:0.420851
# [278]	train-MCC:0.949792	eval-MCC:0.420851
# [279]	train-MCC:0.950674	eval-MCC:0.421514
# [280]	train-MCC:0.951075	eval-MCC:0.421514
# [281]	train-MCC:0.951915	eval-MCC:0.421514
# [282]	train-MCC:0.952394	eval-MCC:0.421514
# [283]	train-MCC:0.953171	eval-MCC:0.421514
# [284]	train-MCC:0.953644	eval-MCC:0.421514
# [285]	train-MCC:0.954027	eval-MCC:0.420948
# [286]	train-MCC:0.954549	eval-MCC:0.420851
# [287]	train-MCC:0.955269	eval-MCC:0.421514
# [288]	train-MCC:0.955651	eval-MCC:0.421514
# [289]	train-MCC:0.956206	eval-MCC:0.421514
# [290]	train-MCC:0.956779	eval-MCC:0.420851
# [291]	train-MCC:0.957166	eval-MCC:0.421037
# [292]	train-MCC:0.957755	eval-MCC:0.421227
# [293]	train-MCC:0.958119	eval-MCC:0.421882
# [294]	train-MCC:0.958332	eval-MCC:0.421882
# [295]	train-MCC:0.958903	eval-MCC:0.421882
# [296]	train-MCC:0.959385	eval-MCC:0.421882
# [297]	train-MCC:0.959944	eval-MCC:0.421882
# [298]	train-MCC:0.960374	eval-MCC:0.421882
# [299]	train-MCC:0.960754	eval-MCC:0.421882
# [300]	train-MCC:0.961078	eval-MCC:0.421882
# [301]	train-MCC:0.961653	eval-MCC:0.422541
# [302]	train-MCC:0.962311	eval-MCC:0.422541
# [303]	train-MCC:0.962596	eval-MCC:0.422541
# [304]	train-MCC:0.963148	eval-MCC:0.422541
# [305]	train-MCC:0.963638	eval-MCC:0.422541
# [306]	train-MCC:0.964195	eval-MCC:0.422071
# [307]	train-MCC:0.964703	eval-MCC:0.422071
# [308]	train-MCC:0.965081	eval-MCC:0.422071
# [309]	train-MCC:0.965365	eval-MCC:0.422071
# [310]	train-MCC:0.965626	eval-MCC:0.422071
# [311]	train-MCC:0.966085	eval-MCC:0.422071
# [312]	train-MCC:0.966475	eval-MCC:0.422071
# [313]	train-MCC:0.967181	eval-MCC:0.422071
# [314]	train-MCC:0.967621	eval-MCC:0.422071
# [315]	train-MCC:0.967763	eval-MCC:0.422456
# [316]	train-MCC:0.968218	eval-MCC:0.422456
# [317]	train-MCC:0.968401	eval-MCC:0.422456
# [318]	train-MCC:0.968852	eval-MCC:0.422456
# [319]	train-MCC:0.969129	eval-MCC:0.422456
# [320]	train-MCC:0.969715	eval-MCC:0.422456
# [321]	train-MCC:0.970018	eval-MCC:0.422456
# [322]	train-MCC:0.970374	eval-MCC:0.422456
# [323]	train-MCC:0.970844	eval-MCC:0.422456
# [324]	train-MCC:0.971115	eval-MCC:0.421811
# [325]	train-MCC:0.971298	eval-MCC:0.422652
# [326]	train-MCC:0.971654	eval-MCC:0.422652
# [327]	train-MCC:0.972024	eval-MCC:0.422359
# [328]	train-MCC:0.972301	eval-MCC:0.422359
# [329]	train-MCC:0.972657	eval-MCC:0.422652
# [330]	train-MCC:0.972934	eval-MCC:0.423492
# [331]	train-MCC:0.973286	eval-MCC:0.423492
# [332]	train-MCC:0.973473	eval-MCC:0.422852
# [333]	train-MCC:0.973795	eval-MCC:0.422852
# [334]	train-MCC:0.974145	eval-MCC:0.422359
# [335]	train-MCC:0.974598	eval-MCC:0.422359
# [336]	train-MCC:0.974867	eval-MCC:0.422359
# [337]	train-MCC:0.975054	eval-MCC:0.422359
# [338]	train-MCC:0.975331	eval-MCC:0.422359
# [339]	train-MCC:0.975515	eval-MCC:0.422256
# [340]	train-MCC:0.975893	eval-MCC:0.422429
# [341]	train-MCC:0.97617	eval-MCC:0.422429
# [342]	train-MCC:0.97635	eval-MCC:0.422429
# [343]	train-MCC:0.976612	eval-MCC:0.422429
# [344]	train-MCC:0.976889	eval-MCC:0.422429
# [345]	train-MCC:0.977073	eval-MCC:0.422429
# [346]	train-MCC:0.977199	eval-MCC:0.422429
# [347]	train-MCC:0.977426	eval-MCC:0.422429
# [348]	train-MCC:0.97773	eval-MCC:0.422213
# [349]	train-MCC:0.977942	eval-MCC:0.421811
# [350]	train-MCC:0.978319	eval-MCC:0.422265
# [351]	train-MCC:0.978592	eval-MCC:0.422265
# [352]	train-MCC:0.978876	eval-MCC:0.422265
# [353]	train-MCC:0.979342	eval-MCC:0.422265
# [354]	train-MCC:0.979898	eval-MCC:0.422265
# [355]	train-MCC:0.980084	eval-MCC:0.422207
# [356]	train-MCC:0.980174	eval-MCC:0.422795
# [357]	train-MCC:0.98036	eval-MCC:0.422754
# [358]	train-MCC:0.980629	eval-MCC:0.422754
# [359]	train-MCC:0.980808	eval-MCC:0.422754
# [360]	train-MCC:0.981058	eval-MCC:0.424128
# [361]	train-MCC:0.98124	eval-MCC:0.424128
# [362]	train-MCC:0.981418	eval-MCC:0.424395
# [363]	train-MCC:0.981857	eval-MCC:0.424395
# [364]	train-MCC:0.982214	eval-MCC:0.424395
# [365]	train-MCC:0.982222	eval-MCC:0.424947
# [366]	train-MCC:0.982534	eval-MCC:0.424947
# [367]	train-MCC:0.982712	eval-MCC:0.424947
# [368]	train-MCC:0.982969	eval-MCC:0.424947
# [369]	train-MCC:0.983244	eval-MCC:0.424947
# [370]	train-MCC:0.98353	eval-MCC:0.424947
# [371]	train-MCC:0.983784	eval-MCC:0.424947
# [372]	train-MCC:0.984062	eval-MCC:0.425501
# [373]	train-MCC:0.984248	eval-MCC:0.425501
# [374]	train-MCC:0.98442	eval-MCC:0.424419
# [375]	train-MCC:0.984506	eval-MCC:0.424682
# [376]	train-MCC:0.984784	eval-MCC:0.425239
# [377]	train-MCC:0.98496	eval-MCC:0.425501
# [378]	train-MCC:0.985238	eval-MCC:0.425501
# [379]	train-MCC:0.985331	eval-MCC:0.425501
# [380]	train-MCC:0.985427	eval-MCC:0.425501
# [381]	train-MCC:0.985517	eval-MCC:0.425501
# [382]	train-MCC:0.985687	eval-MCC:0.425501
# [383]	train-MCC:0.985875	eval-MCC:0.425501
# [384]	train-MCC:0.985928	eval-MCC:0.425239
# [385]	train-MCC:0.986021	eval-MCC:0.425239
# [386]	train-MCC:0.986291	eval-MCC:0.426058
# [387]	train-MCC:0.986382	eval-MCC:0.426058
# [388]	train-MCC:0.986474	eval-MCC:0.426058
# [389]	train-MCC:0.986652	eval-MCC:0.426058
# [390]	train-MCC:0.98684	eval-MCC:0.426058
# [391]	train-MCC:0.98693	eval-MCC:0.42554
# [392]	train-MCC:0.987104	eval-MCC:0.42554
# [393]	train-MCC:0.987115	eval-MCC:0.42554
# [394]	train-MCC:0.987285	eval-MCC:0.426058
# [395]	train-MCC:0.98747	eval-MCC:0.426058
# [396]	train-MCC:0.987556	eval-MCC:0.426058
# [397]	train-MCC:0.987739	eval-MCC:0.426058
# [398]	train-MCC:0.987743	eval-MCC:0.426058
# [399]	train-MCC:0.987743	eval-MCC:0.426058
# [400]	train-MCC:0.987924	eval-MCC:0.426058
# [401]	train-MCC:0.988105	eval-MCC:0.426058
# [402]	train-MCC:0.988107	eval-MCC:0.426058
# [403]	train-MCC:0.988197	eval-MCC:0.426058
# [404]	train-MCC:0.988384	eval-MCC:0.426058
# [405]	train-MCC:0.988384	eval-MCC:0.426058
# [406]	train-MCC:0.988466	eval-MCC:0.426058
# [407]	train-MCC:0.988556	eval-MCC:0.426058
# [408]	train-MCC:0.988647	eval-MCC:0.426058
# [409]	train-MCC:0.988743	eval-MCC:0.426058
# [410]	train-MCC:0.988834	eval-MCC:0.426058
# [411]	train-MCC:0.988924	eval-MCC:0.426058
# [412]	train-MCC:0.98901	eval-MCC:0.426058
# [413]	train-MCC:0.989195	eval-MCC:0.426058
# [414]	train-MCC:0.989196	eval-MCC:0.426058
# [415]	train-MCC:0.98922	eval-MCC:0.426058
# [416]	train-MCC:0.989474	eval-MCC:0.426058
# [417]	train-MCC:0.989654	eval-MCC:0.426058
# [418]	train-MCC:0.989654	eval-MCC:0.426058
# [419]	train-MCC:0.989676	eval-MCC:0.426058
# [420]	train-MCC:0.989768	eval-MCC:0.426058
# [421]	train-MCC:0.98984	eval-MCC:0.427376
# [422]	train-MCC:0.990115	eval-MCC:0.42605
# [423]	train-MCC:0.990117	eval-MCC:0.427376
# [424]	train-MCC:0.990209	eval-MCC:0.427376
# [425]	train-MCC:0.990212	eval-MCC:0.427916
# [426]	train-MCC:0.990303	eval-MCC:0.427916
# [427]	train-MCC:0.990397	eval-MCC:0.427916
# [428]	train-MCC:0.990578	eval-MCC:0.427916
# [429]	train-MCC:0.990673	eval-MCC:0.427916
# [430]	train-MCC:0.990765	eval-MCC:0.427916
# [431]	train-MCC:0.990858	eval-MCC:0.427916
# [432]	train-MCC:0.990947	eval-MCC:0.427916
# [433]	train-MCC:0.99095	eval-MCC:0.427916
# [434]	train-MCC:0.991134	eval-MCC:0.427916
# [435]	train-MCC:0.991225	eval-MCC:0.427646
# [436]	train-MCC:0.991317	eval-MCC:0.427916
# [437]	train-MCC:0.991505	eval-MCC:0.427924
# [438]	train-MCC:0.991595	eval-MCC:0.427646
# [439]	train-MCC:0.991686	eval-MCC:0.427378
# [440]	train-MCC:0.991776	eval-MCC:0.427378
# [441]	train-MCC:0.991686	eval-MCC:0.427916
# [442]	train-MCC:0.991776	eval-MCC:0.42766
# [443]	train-MCC:0.991867	eval-MCC:0.428211
# [444]	train-MCC:0.991958	eval-MCC:0.42795
# [445]	train-MCC:0.992047	eval-MCC:0.429023
# [446]	train-MCC:0.992047	eval-MCC:0.429576
# [447]	train-MCC:0.992139	eval-MCC:0.429576
# [448]	train-MCC:0.992228	eval-MCC:0.429576
# [449]	train-MCC:0.99223	eval-MCC:0.429023
# [450]	train-MCC:0.99223	eval-MCC:0.429023
# [451]	train-MCC:0.99232	eval-MCC:0.428473
# [452]	train-MCC:0.992409	eval-MCC:0.42819
# [453]	train-MCC:0.992501	eval-MCC:0.428458
# [454]	train-MCC:0.992618	eval-MCC:0.428726
# [455]	train-MCC:0.992615	eval-MCC:0.428726
# [456]	train-MCC:0.992796	eval-MCC:0.429267
# [457]	train-MCC:0.992797	eval-MCC:0.429267
# [458]	train-MCC:0.992978	eval-MCC:0.429267
# [459]	train-MCC:0.99307	eval-MCC:0.428726
# [460]	train-MCC:0.993251	eval-MCC:0.429001
# [461]	train-MCC:0.993251	eval-MCC:0.429001
# [462]	train-MCC:0.993341	eval-MCC:0.428996
# [463]	train-MCC:0.993345	eval-MCC:0.429063
# [464]	train-MCC:0.993525	eval-MCC:0.42981
# [465]	train-MCC:0.993613	eval-MCC:0.429267
# [466]	train-MCC:0.993704	eval-MCC:0.429535
# [467]	train-MCC:0.993706	eval-MCC:0.429001
# [468]	train-MCC:0.993794	eval-MCC:0.429535
# [469]	train-MCC:0.993885	eval-MCC:0.429535
# [470]	train-MCC:0.993885	eval-MCC:0.42981
# [471]	train-MCC:0.993885	eval-MCC:0.42981
# [472]	train-MCC:0.993978	eval-MCC:0.42981
# [473]	train-MCC:0.994066	eval-MCC:0.42981
# [474]	train-MCC:0.994066	eval-MCC:0.42981
# [475]	train-MCC:0.994159	eval-MCC:0.42981
# [476]	train-MCC:0.994159	eval-MCC:0.42981
# [477]	train-MCC:0.99425	eval-MCC:0.430356
# [478]	train-MCC:0.994341	eval-MCC:0.42981
# [479]	train-MCC:0.994341	eval-MCC:0.42981
# [480]	train-MCC:0.994431	eval-MCC:0.42981
# [481]	train-MCC:0.994431	eval-MCC:0.42981
# [482]	train-MCC:0.994431	eval-MCC:0.42981
# [483]	train-MCC:0.994431	eval-MCC:0.429284
# [484]	train-MCC:0.99461	eval-MCC:0.42981
# [485]	train-MCC:0.994703	eval-MCC:0.42981
# [486]	train-MCC:0.99488	eval-MCC:0.429547
# [487]	train-MCC:0.99488	eval-MCC:0.429007
# [488]	train-MCC:0.995066	eval-MCC:0.429371
# [489]	train-MCC:0.995157	eval-MCC:0.428473
# [490]	train-MCC:0.995157	eval-MCC:0.428726
# [491]	train-MCC:0.995157	eval-MCC:0.428556
# [492]	train-MCC:0.995248	eval-MCC:0.428726
# [493]	train-MCC:0.995339	eval-MCC:0.429267
# [494]	train-MCC:0.99543	eval-MCC:0.429267
# [495]	train-MCC:0.99543	eval-MCC:0.429267
# [496]	train-MCC:0.99543	eval-MCC:0.429267
# [497]	train-MCC:0.995521	eval-MCC:0.429007
# [498]	train-MCC:0.995521	eval-MCC:0.429319
# [499]	train-MCC:0.99561	eval-MCC:0.429319
# [500]	train-MCC:0.995613	eval-MCC:0.429319
# [501]	train-MCC:0.995613	eval-MCC:0.429319
# [502]	train-MCC:0.995704	eval-MCC:0.429023
# [503]	train-MCC:0.995704	eval-MCC:0.429576
# [504]	train-MCC:0.995795	eval-MCC:0.42954
# [505]	train-MCC:0.995977	eval-MCC:0.43061
# [506]	train-MCC:0.995977	eval-MCC:0.43061
# [507]	train-MCC:0.996066	eval-MCC:0.429814
# [508]	train-MCC:0.996066	eval-MCC:0.429814
# [509]	train-MCC:0.996067	eval-MCC:0.429814
# [510]	train-MCC:0.996159	eval-MCC:0.42954
# [511]	train-MCC:0.99616	eval-MCC:0.43061
# [512]	train-MCC:0.996251	eval-MCC:0.43061
# [513]	train-MCC:0.996349	eval-MCC:0.43061
# [514]	train-MCC:0.996349	eval-MCC:0.43061
# [515]	train-MCC:0.996349	eval-MCC:0.430074
# [516]	train-MCC:0.99644	eval-MCC:0.430074
# [517]	train-MCC:0.996622	eval-MCC:0.430074
# [518]	train-MCC:0.996622	eval-MCC:0.430074
# [519]	train-MCC:0.996622	eval-MCC:0.430346
# [520]	train-MCC:0.996622	eval-MCC:0.430346
# [521]	train-MCC:0.996713	eval-MCC:0.430879
# [522]	train-MCC:0.996713	eval-MCC:0.430883
# [523]	train-MCC:0.996804	eval-MCC:0.430879
# [524]	train-MCC:0.996895	eval-MCC:0.430879
# [525]	train-MCC:0.996986	eval-MCC:0.430879
# [526]	train-MCC:0.996986	eval-MCC:0.430342
# [527]	train-MCC:0.997077	eval-MCC:0.430342
# [528]	train-MCC:0.997077	eval-MCC:0.430342
# [529]	train-MCC:0.997077	eval-MCC:0.430342
# [530]	train-MCC:0.997077	eval-MCC:0.430399
# [531]	train-MCC:0.997077	eval-MCC:0.430365
# [532]	train-MCC:0.997077	eval-MCC:0.430365
# [533]	train-MCC:0.997077	eval-MCC:0.430365
# [534]	train-MCC:0.997167	eval-MCC:0.430883
# [535]	train-MCC:0.997258	eval-MCC:0.430365
# [536]	train-MCC:0.99735	eval-MCC:0.430642
# [537]	train-MCC:0.99735	eval-MCC:0.430642
# [538]	train-MCC:0.997441	eval-MCC:0.43115
# [539]	train-MCC:0.997442	eval-MCC:0.430642
# [540]	train-MCC:0.997533	eval-MCC:0.43115
# [541]	train-MCC:0.997533	eval-MCC:0.430642
# [542]	train-MCC:0.997533	eval-MCC:0.430642
# [543]	train-MCC:0.997533	eval-MCC:0.431167
# [544]	train-MCC:0.997533	eval-MCC:0.431167
# [545]	train-MCC:0.997533	eval-MCC:0.431167
# [546]	train-MCC:0.997533	eval-MCC:0.431167
# [547]	train-MCC:0.997534	eval-MCC:0.431695
# [548]	train-MCC:0.997534	eval-MCC:0.431695
# [549]	train-MCC:0.997716	eval-MCC:0.431695
# [550]	train-MCC:0.997716	eval-MCC:0.431695
# [551]	train-MCC:0.997716	eval-MCC:0.431695
# [552]	train-MCC:0.997716	eval-MCC:0.431695
# [553]	train-MCC:0.997716	eval-MCC:0.431953
# [554]	train-MCC:0.997717	eval-MCC:0.432755
# [555]	train-MCC:0.997717	eval-MCC:0.432755
# [556]	train-MCC:0.997717	eval-MCC:0.432224
# [557]	train-MCC:0.997808	eval-MCC:0.432755
# [558]	train-MCC:0.99781	eval-MCC:0.432755
# [559]	train-MCC:0.9979	eval-MCC:0.432486
# [560]	train-MCC:0.997992	eval-MCC:0.432486
# [561]	train-MCC:0.997992	eval-MCC:0.432486
# [562]	train-MCC:0.998083	eval-MCC:0.432486
# [563]	train-MCC:0.998174	eval-MCC:0.433022
# [564]	train-MCC:0.998174	eval-MCC:0.433022
# [565]	train-MCC:0.998174	eval-MCC:0.433022
# [566]	train-MCC:0.998174	eval-MCC:0.433022
# [567]	train-MCC:0.998174	eval-MCC:0.433022
# [568]	train-MCC:0.998265	eval-MCC:0.433559
# [569]	train-MCC:0.998265	eval-MCC:0.433559
# [570]	train-MCC:0.998265	eval-MCC:0.433559
# [571]	train-MCC:0.998265	eval-MCC:0.433559
# [572]	train-MCC:0.998265	eval-MCC:0.433559
# [573]	train-MCC:0.998265	eval-MCC:0.433559
# [574]	train-MCC:0.998356	eval-MCC:0.433559
# [575]	train-MCC:0.998356	eval-MCC:0.433559
# [576]	train-MCC:0.998356	eval-MCC:0.433296
# [577]	train-MCC:0.998356	eval-MCC:0.433559
# [578]	train-MCC:0.998356	eval-MCC:0.433559
# [579]	train-MCC:0.998356	eval-MCC:0.433559
# [580]	train-MCC:0.998356	eval-MCC:0.433559
# [581]	train-MCC:0.998356	eval-MCC:0.433296
# [582]	train-MCC:0.998448	eval-MCC:0.433838
# [583]	train-MCC:0.998448	eval-MCC:0.433838
# [584]	train-MCC:0.998448	eval-MCC:0.433838
# [585]	train-MCC:0.998448	eval-MCC:0.433838
# [586]	train-MCC:0.998539	eval-MCC:0.433838
# [587]	train-MCC:0.99863	eval-MCC:0.433838
# [588]	train-MCC:0.99863	eval-MCC:0.433838
# [589]	train-MCC:0.99863	eval-MCC:0.433838
# [590]	train-MCC:0.998721	eval-MCC:0.433838
# [591]	train-MCC:0.998721	eval-MCC:0.434927
# [592]	train-MCC:0.998721	eval-MCC:0.434381
# [593]	train-MCC:0.998721	eval-MCC:0.434381
# [594]	train-MCC:0.998721	eval-MCC:0.433838
# [595]	train-MCC:0.998721	eval-MCC:0.433838
# [596]	train-MCC:0.998721	eval-MCC:0.433296
# [597]	train-MCC:0.998812	eval-MCC:0.433296
# [598]	train-MCC:0.998812	eval-MCC:0.434381
# [599]	train-MCC:0.998812	eval-MCC:0.434381
# [600]	train-MCC:0.998904	eval-MCC:0.434381
# [601]	train-MCC:0.998904	eval-MCC:0.433869
# [602]	train-MCC:0.998904	eval-MCC:0.433869
# [603]	train-MCC:0.998904	eval-MCC:0.434125
# [604]	train-MCC:0.998904	eval-MCC:0.434125
# [605]	train-MCC:0.998995	eval-MCC:0.433869
# [606]	train-MCC:0.998995	eval-MCC:0.433869
# [607]	train-MCC:0.999086	eval-MCC:0.433296
# [608]	train-MCC:0.999086	eval-MCC:0.433869
# [609]	train-MCC:0.999086	eval-MCC:0.433579
# [610]	train-MCC:0.999086	eval-MCC:0.433836
# [611]	train-MCC:0.999086	eval-MCC:0.433616
# [612]	train-MCC:0.999086	eval-MCC:0.433616
# [613]	train-MCC:0.999086	eval-MCC:0.433616
# [614]	train-MCC:0.999177	eval-MCC:0.433838
# [615]	train-MCC:0.999177	eval-MCC:0.433616
# [616]	train-MCC:0.999177	eval-MCC:0.433616
# [617]	train-MCC:0.999177	eval-MCC:0.433616
# [618]	train-MCC:0.999177	eval-MCC:0.433616
# [619]	train-MCC:0.999177	eval-MCC:0.433616
# [620]	train-MCC:0.999177	eval-MCC:0.433616
# [621]	train-MCC:0.999178	eval-MCC:0.433616
# [622]	train-MCC:0.999178	eval-MCC:0.433065
# [623]	train-MCC:0.999269	eval-MCC:0.433065
# [624]	train-MCC:0.999269	eval-MCC:0.433065
# [625]	train-MCC:0.999269	eval-MCC:0.433065
# [626]	train-MCC:0.999269	eval-MCC:0.433065
# [627]	train-MCC:0.999269	eval-MCC:0.433065
# [628]	train-MCC:0.999269	eval-MCC:0.433065
# [629]	train-MCC:0.999269	eval-MCC:0.433616
# [630]	train-MCC:0.999269	eval-MCC:0.433616
# [631]	train-MCC:0.999269	eval-MCC:0.433616
# [632]	train-MCC:0.99936	eval-MCC:0.433616
# [633]	train-MCC:0.99936	eval-MCC:0.433616
# [634]	train-MCC:0.99936	eval-MCC:0.433616
# [635]	train-MCC:0.99936	eval-MCC:0.433838
# [636]	train-MCC:0.99936	eval-MCC:0.433616
# [637]	train-MCC:0.99936	eval-MCC:0.433616
# [638]	train-MCC:0.99936	eval-MCC:0.434381
# [639]	train-MCC:0.99936	eval-MCC:0.433838
# [640]	train-MCC:0.99936	eval-MCC:0.434381
# [641]	train-MCC:0.999452	eval-MCC:0.433838
# [642]	train-MCC:0.999452	eval-MCC:0.433838
# [643]	train-MCC:0.999452	eval-MCC:0.433838
# [644]	train-MCC:0.999452	eval-MCC:0.433616
# [645]	train-MCC:0.999452	eval-MCC:0.433838
# [646]	train-MCC:0.999452	eval-MCC:0.433838
# [647]	train-MCC:0.999452	eval-MCC:0.433065
# [648]	train-MCC:0.999452	eval-MCC:0.433579
# [649]	train-MCC:0.999452	eval-MCC:0.433579
# [650]	train-MCC:0.999452	eval-MCC:0.433579
# [651]	train-MCC:0.999452	eval-MCC:0.433579
# [652]	train-MCC:0.999452	eval-MCC:0.433579
# [653]	train-MCC:0.999452	eval-MCC:0.433579
# [654]	train-MCC:0.999452	eval-MCC:0.433579
# [655]	train-MCC:0.999452	eval-MCC:0.433579
# [656]	train-MCC:0.999452	eval-MCC:0.43372
# [657]	train-MCC:0.999543	eval-MCC:0.433838
# [658]	train-MCC:0.999543	eval-MCC:0.434381
# [659]	train-MCC:0.999543	eval-MCC:0.434381
# [660]	train-MCC:0.999634	eval-MCC:0.434639
# [661]	train-MCC:0.999634	eval-MCC:0.434381
# [662]	train-MCC:0.999634	eval-MCC:0.434639
# [663]	train-MCC:0.999634	eval-MCC:0.434381
# [664]	train-MCC:0.999634	eval-MCC:0.434381
# [665]	train-MCC:0.999634	eval-MCC:0.434381
# [666]	train-MCC:0.999634	eval-MCC:0.434098
# [667]	train-MCC:0.999634	eval-MCC:0.434098
# [668]	train-MCC:0.999634	eval-MCC:0.434098
# [669]	train-MCC:0.999634	eval-MCC:0.434098
# [670]	train-MCC:0.999634	eval-MCC:0.434098
# [671]	train-MCC:0.999634	eval-MCC:0.434639
# [672]	train-MCC:0.999634	eval-MCC:0.434098
# [673]	train-MCC:0.999634	eval-MCC:0.434098
# [674]	train-MCC:0.999634	eval-MCC:0.434098
# [675]	train-MCC:0.999634	eval-MCC:0.433838
# [676]	train-MCC:0.999634	eval-MCC:0.433838
# [677]	train-MCC:0.999634	eval-MCC:0.433838
# [678]	train-MCC:0.999634	eval-MCC:0.433838
# [679]	train-MCC:0.999634	eval-MCC:0.43372
# [680]	train-MCC:0.999634	eval-MCC:0.433206
# [681]	train-MCC:0.999634	eval-MCC:0.43372
# [682]	train-MCC:0.999634	eval-MCC:0.43372
# [683]	train-MCC:0.999634	eval-MCC:0.433493
# [684]	train-MCC:0.999634	eval-MCC:0.433559
# [685]	train-MCC:0.999634	eval-MCC:0.433579
# [686]	train-MCC:0.999634	eval-MCC:0.433579
# [687]	train-MCC:0.999634	eval-MCC:0.433579
# [688]	train-MCC:0.999634	eval-MCC:0.433579
# [689]	train-MCC:0.999634	eval-MCC:0.433579
# [690]	train-MCC:0.999634	eval-MCC:0.434125
# [691]	train-MCC:0.999634	eval-MCC:0.434125
# Stopping. Best iteration:
# [591]	train-MCC:0.998721	eval-MCC:0.434927

# %%
import operator
importance = bst1.get_fscore(fmap='xgb1.fmap')
importance = sorted(importance.items(), key=operator.itemgetter(1), reverse=True)

# %%
len(importance)
# Out:
# 752

# %%
bst1.dump_model('434927mcc.dump', fmap='xgb1.fmap', with_stats=True)

# %%
bst1.save_model('434927.model')

# %%
#bst1 = xgb.Booster()
#bst1.load_model('429535.model')

# %%
pred_valid = bst1.predict(dvalid, ntree_limit=155)

# %%
best_proba, best_mcc, y_pred = eval_mcc(dvalid.get_label(), pred_valid, show=True)
# Out:
# 0.429534884036 0.4295348840357449

# %%
best_proba
# Out:
# 0.29268866777420044

# %%
dtest = xgb.DMatrix('../input_hdf/test_with_faron_sel.buffer')

# %%
# generate predictions at the chosen threshold
preds = (bst1.predict(dtest, ntree_limit=155) > best_proba).astype(np.int8)

# %%
# and submit
sub = pd.read_csv("../input_orig/sample_submission.csv", index_col=0)
sub["Response"] = preds
sub.to_csv("429535_submission.csv.gz", compression="gzip")
